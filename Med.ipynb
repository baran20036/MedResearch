# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
medications = pd.DataFrame.from_csv('data/medications.csv', index_col= None , encoding='utf-8')    
los = pd.DataFrame.from_csv('data/los.csv', index_col= None , encoding='utf-8') 
med = medications.dropna()
med['pt']= med['pt'].astype(int)
med.head(4)
# Out:
# /Users/fereshtehpalmer/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          pt       Admit Date & Time   Discharge Date & Time  \
# 0  29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 1  29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 2  29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 3  29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
#
#                    Order Mnemonic Administration Date and Time  \
# 0  acetaminophen liquid 325 mg UD       01/01/2015 01:57:55 AM
# 1  acetaminophen liquid 325 mg UD       01/01/2015 08:28:42 PM
# 2  acetaminophen liquid 325 mg UD       01/03/2015 09:53:07 AM
# ...

# %%
med['pt'] = med['pt'].astype(int)
med
# Out:
# /Users/fereshtehpalmer/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#              pt       Admit Date & Time   Discharge Date & Time  \
# 0      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 1      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 2      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 3      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 4      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 5      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 6      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 7      29796017  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# ...

# %%
los.head()
# Out:
#          pt  LOS-d
# 0  29796017  32.81
# 1  29997323   6.14
# 2  30025987   1.78
# 3  30037900   6.69
# 4  30062711  15.34

# %%
los.dtypes
# Out:
# pt         int64
# LOS-d    float64
# dtype: object

# %%
med = medications
med.dtypes
# Out:
# pt                              float64
# Admit Date & Time                object
# Discharge Date & Time            object
# Order Mnemonic                   object
# Administration Date and Time     object
# Order Clinical Category          object
# dtype: object

# %%
med.rename(columns = {'Order Mnemonic': 'order'}, inplace = True)
med
# Out:
#                pt       Admit Date & Time   Discharge Date & Time  \
# 0      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 1      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 2      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 3      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 4      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 5      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 6      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 7      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 8      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 9      29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 10     29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 11     29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# 12     29796017.0  12/06/2014 04:45:00 PM  01/08/2015 12:12:00 PM
# ...

# %%
#med = med.set_index('pt')
#med['Order Mnemonic'] = med['order']

# %%
# GROUPBY EXAMPLES: brandon 1:34

#df2 = df.groupby([df.year // 10 *10, 'type']).size()  **acts like subtotal
#df2.unstack()                                         ** gives crosstab table
#df2.unstack(0)                                        ** switches header and column 1:42
#df2['column 1'] - df2['column 2']       
#df.fillna('0)                                         ** puts blank instead of NaN
#df['new column'] = 1                                  ** adds a new column and fills it with 1
#df3 = df.set_index('new column', append=True)         ** sets the new column as index without removing the od index  1:52

## df = df.groupby(['year'], ['type']).size()          * this function groups the data and unstack compares the values inside 'type' column
## df = df.unstack('type')                               watch 1:58 for plots

#(c.actor / (c.actor + c.actress)).plot(ylim=(0,1))    * take into concideration the sample size and set y between 0 and 1 2:00

# c = c.groupby(['year', 'type', 'n']).size()          * this formula compares 3 dimetions and creates 3 line graphs 2:03
# c = c.unstack('type')
#(c.actor / (c.actor + c.actress)).unstack('n').plot(ylim=(0,1)) 

####  DATE TIME OPERATIONS .dt ####   2:07

#df.column name.dt.year
#df.column name.dt.month
#df.column name.dt.day
#df.column name.dt.dayofmonth
#df.column name.dt.dayofweek

#### MERGE ####

# df = df[df.column == 'ellen page'] 2:11               * join is a merge with more defined objects. Merge is more general. 
# df.merge[second df]
 
# **** PIVOT **** #   2:12

# r = release_dates      this is a df
# r = r[r.title.str.startswith('star wars: Episode')]
# r = r[r.country.str.startswith('U')]
# r.pivot('title', 'country', 'date')

#**** Extract from column 1 and add the extraction to the last column ****#  2:21 

### TOP 10 groupped values ###

#df2 = df1.groupby(['countryname']).size()
#df3 = df2.nlargest(10)
#df3

# %%
AB = med.groupby(['pt','order']).size()
AB
# Out:
# pt          order
# 29796017.0  Aquaphor Healing Ointment 50 g                                                                   1
#             D5W  0.9% NaCl inj 500 ml                                                                       58
#             FAMotidine 4 mg/ml in D5W inj                                                                    5
#             METHadone oral solution                                                                         13
#             Methadone *Dil* 1 mg/ml in NS inj 1 ml vial                                                     12
#             PHOS-NaK (Neutra-Phos) 8 mMol powder pkt                                                         1
#             Sodium Chloride 0.9% inj 49.3 ml + papaverine inj 6 mg + heparin 100 units/ml inj 50 Unit(s)    15
#             Sodium Chloride 0.9% inj 49.5 ml + heparin 100 units/ml inj 50 Unit(s)                          46
# ...

# %%
#AB.str.find(sub, start=0, end=None)vancomycin
help(str)
# Out:
# Help on class str in module __builtin__:
#
# class str(basestring)
#  |  str(object='') -> string
#  |
#  |  Return a nice string representation of the object.
#  |  If the argument is a string, the return value is the same object.
#  |
#  |  Method resolution order:
#  |      str
#  |      basestring
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __add__(...)
#  |      x.__add__(y) <==> x+y
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x
#  |
#  |  __eq__(...)
#  |      x.__eq__(y) <==> x==y
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> string
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(...)
#  |      x.__ge__(y) <==> x>=y
#  |
#  |  __getattribute__(...)
#  |      x.__getattribute__('name') <==> x.name
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __getnewargs__(...)
#  |
#  |  __getslice__(...)
#  |      x.__getslice__(i, j) <==> x[i:j]
#  |
# ...

# %%
vanco = AB[AB['order'].str.contains('vancomycin')]
#df[df['category'].str.contains('national')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-b532c9afb2fa> in <module>()
# ----> 1 vanco = AB[AB['order'].str.contains('vancomycin')]
#       2 #df[df['category'].str.contains('national')]
#
# /Users/fereshtehpalmer/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     581         key = com._apply_if_callable(key, self)
#     582         try:
# --> 583             result = self.index.get_value(self, key)
#     584
#     585             if not lib.isscalar(result):
#
# /Users/fereshtehpalmer/anaconda/lib/python2.7/site-packages/pandas/indexes/multi.pyc in get_value(self, series, key)
#     624                     raise InvalidIndexError(key)
#     625                 else:
# --> 626                     raise e1
#     627             except Exception:  # pragma: no cover
#     628                 raise e1
#
# ...

# %%
#los.head()
MLOS = los.pt.astype(str), los.LOS-d.astype(float)
MLOS
los.plot(x='LOS-d', y = 'pt')

# %%
med['pt']

# %%
med = med.dropna()
med

# %%
med['pt'] = med['pt'].astype(int)
med
